# %%
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as pyplot

# %%
filepath = '../data/2018_Sales_Total.xlsx'
sales = pd.read_excel(filepath)

# %%
sales.head()
# Out:
#    account number                         name       sku  quantity  \
# 0          740150                   Barton LLC  B1-20000        39
# 1          714466              Trantow-Barrows  S2-77896        -1
# 2          218895                    Kulas Inc  B1-69924        23
# 3          307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4          412290                Jerde-Hilpert  S2-34077         6
#
#    unit price  ext price                date
# 0       86.69    3380.91 2018-01-01 07:21:51
# 1       63.16     -63.16 2018-01-01 10:00:47
# 2       90.70    2086.10 2018-01-01 13:24:58
# 3       21.05     863.05 2018-01-01 15:05:22
# 4       83.21     499.26 2018-01-01 23:26:55

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   account number  1500 non-null   int64
#  1   name            1500 non-null   object
#  2   sku             1500 non-null   object
#  3   quantity        1500 non-null   int64
#  4   unit price      1500 non-null   float64
#  5   ext price       1500 non-null   float64
#  6   date            1500 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 82.2+ KB

# %%
sales.describe()
# Out:
#        account number     quantity   unit price    ext price
# count     1500.000000  1500.000000  1500.000000  1500.000000
# mean    485957.841333    24.308667    55.007527  1345.856213
# std     223974.044572    14.439265    25.903267  1084.914881
# min     141962.000000    -1.000000    10.030000   -97.160000
# 25%     257198.000000    12.000000    32.500000   472.177500
# 50%     527099.000000    25.000000    55.465000  1050.390000
# 75%     714466.000000    37.000000    77.075000  2068.330000
# max     786968.000000    49.000000    99.850000  4824.540000

# %%
sales.columns = [re.sub(r'[\s\\,\?]+', '_', col.lower()) for col in sales.columns]
list(sales.columns)
# Out:
# ['account_number',
#  'name',
#  'sku',
#  'quantity',
#  'unit_price',
#  'ext_price',
#  'date']

# %%
aggdf = sales.groupby('name')['ext_price'].agg(['mean', 'sum']).iloc[:5, :]
aggdf.head()
# Out:
#                                         mean        sum
# name
# Barton LLC                       1334.615854  109438.50
# Cronin, Oberbrunner and Spencer  1339.321642   89734.55
# Frami, Hills and Schmidt         1438.466528  103569.59
# Fritsch, Russel and Anderson     1385.366790  112214.71
# Halvorson, Crona and Champlin    1206.971724   70004.36

# %% [markdown]
# ## 1. Style numeric numbers
#
# Refer this [cookbook](https://mkaz.blog/code/python-string-format-cookbook/) to find the formatting rules. ':' is the separator between the variable name and formatting string. See the example below:

# %%
a = 2.2222222
b = 3.3333333
f"{a:.2f} != {a:.3f} and {a:.3f} < {b:.3f}"
# Out:
# '2.22 != 2.222 and 2.222 < 3.333'

# %%
aggdf.style.format('{:.2f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >mean</th>        <th class="col_heading level0 col1" >sum</th>    </tr>    <tr>        <th class="index_name level0" >name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5level0_row0" class="row_heading level0 row0" >Barton LLC</th>
#                         <td id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5row0_col0" class="data row0 col0" >1334.62</td>
#                         <td id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5row0_col1" class="data row0 col1" >109438.50</td>
#             </tr>
#             <tr>
#                         <th id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5level0_row1" class="row_heading level0 row1" >Cronin, Oberbrunner and Spencer</th>
#                         <td id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5row1_col0" class="data row1 col0" >1339.32</td>
#                         <td id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5row1_col1" class="data row1 col1" >89734.55</td>
#             </tr>
#             <tr>
#                         <th id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5level0_row2" class="row_heading level0 row2" >Frami, Hills and Schmidt</th>
#                         <td id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5row2_col0" class="data row2 col0" >1438.47</td>
#                         <td id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5row2_col1" class="data row2 col1" >103569.59</td>
#             </tr>
#             <tr>
#                         <th id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5level0_row3" class="row_heading level0 row3" >Fritsch, Russel and Anderson</th>
#                         <td id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5row3_col0" class="data row3 col0" >1385.37</td>
#                         <td id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5row3_col1" class="data row3 col1" >112214.71</td>
#             </tr>
#             <tr>
#                         <th id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5level0_row4" class="row_heading level0 row4" >Halvorson, Crona and Champlin</th>
#                         <td id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5row4_col0" class="data row4 col0" >1206.97</td>
#                         <td id="T_8f89e20c_3ffb_11eb_ac34_a4bb6d40d5e5row4_col1" class="data row4 col1" >70004.36</td>
#             </tr>
#     </tbody></table>

# %%
aggdf.style.format('{:,.2f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >mean</th>        <th class="col_heading level0 col1" >sum</th>    </tr>    <tr>        <th class="index_name level0" >name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5level0_row0" class="row_heading level0 row0" >Barton LLC</th>
#                         <td id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5row0_col0" class="data row0 col0" >1,334.62</td>
#                         <td id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5row0_col1" class="data row0 col1" >109,438.50</td>
#             </tr>
#             <tr>
#                         <th id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5level0_row1" class="row_heading level0 row1" >Cronin, Oberbrunner and Spencer</th>
#                         <td id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5row1_col0" class="data row1 col0" >1,339.32</td>
#                         <td id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5row1_col1" class="data row1 col1" >89,734.55</td>
#             </tr>
#             <tr>
#                         <th id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5level0_row2" class="row_heading level0 row2" >Frami, Hills and Schmidt</th>
#                         <td id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5row2_col0" class="data row2 col0" >1,438.47</td>
#                         <td id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5row2_col1" class="data row2 col1" >103,569.59</td>
#             </tr>
#             <tr>
#                         <th id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5level0_row3" class="row_heading level0 row3" >Fritsch, Russel and Anderson</th>
#                         <td id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5row3_col0" class="data row3 col0" >1,385.37</td>
#                         <td id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5row3_col1" class="data row3 col1" >112,214.71</td>
#             </tr>
#             <tr>
#                         <th id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5level0_row4" class="row_heading level0 row4" >Halvorson, Crona and Champlin</th>
#                         <td id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5row4_col0" class="data row4 col0" >1,206.97</td>
#                         <td id="T_8fe9ea1a_3ffb_11eb_ade0_a4bb6d40d5e5row4_col1" class="data row4 col1" >70,004.36</td>
#             </tr>
#     </tbody></table>

# %%
# Use formatter dictionary to format multiple columns
formatter = {'mean': '{:.2f}', 'sum': '{:.3f}'}
aggdf.style.format(formatter)
# Out:
# <style  type="text/css" >
# </style><table id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >mean</th>        <th class="col_heading level0 col1" >sum</th>    </tr>    <tr>        <th class="index_name level0" >name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5level0_row0" class="row_heading level0 row0" >Barton LLC</th>
#                         <td id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5row0_col0" class="data row0 col0" >1334.62</td>
#                         <td id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5row0_col1" class="data row0 col1" >109438.500</td>
#             </tr>
#             <tr>
#                         <th id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5level0_row1" class="row_heading level0 row1" >Cronin, Oberbrunner and Spencer</th>
#                         <td id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5row1_col0" class="data row1 col0" >1339.32</td>
#                         <td id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5row1_col1" class="data row1 col1" >89734.550</td>
#             </tr>
#             <tr>
#                         <th id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5level0_row2" class="row_heading level0 row2" >Frami, Hills and Schmidt</th>
#                         <td id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5row2_col0" class="data row2 col0" >1438.47</td>
#                         <td id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5row2_col1" class="data row2 col1" >103569.590</td>
#             </tr>
#             <tr>
#                         <th id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5level0_row3" class="row_heading level0 row3" >Fritsch, Russel and Anderson</th>
#                         <td id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5row3_col0" class="data row3 col0" >1385.37</td>
#                         <td id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5row3_col1" class="data row3 col1" >112214.710</td>
#             </tr>
#             <tr>
#                         <th id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5level0_row4" class="row_heading level0 row4" >Halvorson, Crona and Champlin</th>
#                         <td id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5row4_col0" class="data row4 col0" >1206.97</td>
#                         <td id="T_9d302574_3ffb_11eb_8ac1_a4bb6d40d5e5row4_col1" class="data row4 col1" >70004.360</td>
#             </tr>
#     </tbody></table>

# %%
# Doesn't display the index columns 
aggdf.iloc[:5, :].style.format('{:.2f}').hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5" ><thead>    <tr>        <th class="col_heading level0 col0" >mean</th>        <th class="col_heading level0 col1" >sum</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5row0_col0" class="data row0 col0" >1334.62</td>
#                         <td id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5row0_col1" class="data row0 col1" >109438.50</td>
#             </tr>
#             <tr>
#                                 <td id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5row1_col0" class="data row1 col0" >1339.32</td>
#                         <td id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5row1_col1" class="data row1 col1" >89734.55</td>
#             </tr>
#             <tr>
#                                 <td id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5row2_col0" class="data row2 col0" >1438.47</td>
#                         <td id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5row2_col1" class="data row2 col1" >103569.59</td>
#             </tr>
#             <tr>
#                                 <td id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5row3_col0" class="data row3 col0" >1385.37</td>
#                         <td id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5row3_col1" class="data row3 col1" >112214.71</td>
#             </tr>
#             <tr>
#                                 <td id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5row4_col0" class="data row4 col0" >1206.97</td>
#                         <td id="T_9efb7778_3ffb_11eb_9907_a4bb6d40d5e5row4_col1" class="data row4 col1" >70004.36</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# If we want to look at total sales by each month, we can use the `resample` to summarize by month and also calculate how much each month is as a percentage of the total annual sales.
#
# `resample` is `groupby` based on datetime. See [doc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html).

# %%
sales2 = sales.copy()
sales2.date = pd.to_datetime(sales2.date, format='%Y-%d-%m %H:%M:%s') # Add format is highly suggested, much faster
sales2.dtypes
# Out:
# account_number             int64
# name                      object
# sku                       object
# quantity                   int64
# unit_price               float64
# ext_price                float64
# date              datetime64[ns]
# dtype: object

# %%
sales2.head()
# Out:
#    account_number                         name       sku  quantity  \
# 0          740150                   Barton LLC  B1-20000        39
# 1          714466              Trantow-Barrows  S2-77896        -1
# 2          218895                    Kulas Inc  B1-69924        23
# 3          307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4          412290                Jerde-Hilpert  S2-34077         6
#
#    unit_price  ext_price                date
# 0       86.69    3380.91 2018-01-01 07:21:51
# 1       63.16     -63.16 2018-01-01 10:00:47
# 2       90.70    2086.10 2018-01-01 13:24:58
# 3       21.05     863.05 2018-01-01 15:05:22
# 4       83.21     499.26 2018-01-01 23:26:55

# %%
monthly_sales = sales2.resample('M', on='date')['ext_price'].agg('sum').reset_index()
# 'M' is the frequency, i.e. groupby month; on='date' can be ignored if we set 'date' as index
monthly_sales.head()
# Out:
#         date  ext_price
# 0 2018-01-31  185361.66
# 1 2018-02-28  146211.62
# 2 2018-03-31  203921.38
# 3 2018-04-30  174574.11
# 4 2018-05-31  165418.55

# %%
monthly_sales['pct_of_total'] = monthly_sales['ext_price'] / sales2['ext_price'].sum()
monthly_sales.head()
# Out:
#         date  ext_price  pct_of_total
# 0 2018-01-31  185361.66      0.091818
# 1 2018-02-28  146211.62      0.072426
# 2 2018-03-31  203921.38      0.101012
# 3 2018-04-30  174574.11      0.086475
# 4 2018-05-31  165418.55      0.081940

# %%
formatter = {'date': '{:%Y-%m}', 'ext_price': '{:,.0f}', 'pct_of_total': '{:.2%}'}
monthly_sales.style.format(formatter).hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5" ><thead>    <tr>        <th class="col_heading level0 col0" >date</th>        <th class="col_heading level0 col1" >ext_price</th>        <th class="col_heading level0 col2" >pct_of_total</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row0_col0" class="data row0 col0" >2018-01</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row0_col1" class="data row0 col1" >185,362</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row0_col2" class="data row0 col2" >9.18%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row1_col0" class="data row1 col0" >2018-02</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row1_col1" class="data row1 col1" >146,212</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row1_col2" class="data row1 col2" >7.24%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row2_col0" class="data row2 col0" >2018-03</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row2_col1" class="data row2 col1" >203,921</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row2_col2" class="data row2 col2" >10.10%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row3_col0" class="data row3 col0" >2018-04</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row3_col1" class="data row3 col1" >174,574</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row3_col2" class="data row3 col2" >8.65%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row4_col0" class="data row4 col0" >2018-05</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row4_col1" class="data row4 col1" >165,419</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row4_col2" class="data row4 col2" >8.19%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row5_col0" class="data row5 col0" >2018-06</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row5_col1" class="data row5 col1" >174,089</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row5_col2" class="data row5 col2" >8.62%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row6_col0" class="data row6 col0" >2018-07</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row6_col1" class="data row6 col1" >191,662</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row6_col2" class="data row6 col2" >9.49%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row7_col0" class="data row7 col0" >2018-08</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row7_col1" class="data row7 col1" >153,779</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row7_col2" class="data row7 col2" >7.62%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row8_col0" class="data row8 col0" >2018-09</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row8_col1" class="data row8 col1" >168,443</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row8_col2" class="data row8 col2" >8.34%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row9_col0" class="data row9 col0" >2018-10</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row9_col1" class="data row9 col1" >171,495</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row9_col2" class="data row9 col2" >8.49%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row10_col0" class="data row10 col0" >2018-11</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row10_col1" class="data row10 col1" >119,961</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row10_col2" class="data row10 col2" >5.94%</td>
#             </tr>
#             <tr>
#                                 <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row11_col0" class="data row11 col0" >2018-12</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row11_col1" class="data row11 col1" >163,867</td>
#                         <td id="T_427508a2_3ffc_11eb_a9d6_a4bb6d40d5e5row11_col2" class="data row11 col2" >8.12%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 2. Highlight the data cell
#
# In addition to styling numbers, we can also style the cells in the DataFrame.
#
# ### 2.1 Highlight max, min and null
#
# You can highlight the max (`highlight_max`), min (`highlight_min`) and null (`highlight_null`) values of the dataframe. Refer to [doc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.io.formats.style.Styler.highlight_max.html) for more details.
#
# There are three control parameters:
#
# - subset: a slice of columns/rows to highlight
# - color: highlight color
# - axis: axis of the dataframe

# %%
# Highlight the max and min using different colors
monthly_sales.style.format(formatter).hide_index()\
    .highlight_max(color='lightgreen')\
    .highlight_min(subset=['pct_of_total'], color='#cd4f39')  # Use subset to choose the columns to highlight
# Out:
# <style  type="text/css" >
#     #T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row2_col1 {
#             background-color:  lightgreen;
#         }    #T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row2_col2 {
#             background-color:  lightgreen;
#             : ;
#         }    #T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row10_col2 {
#             : ;
#             background-color:  #cd4f39;
#         }</style><table id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5" ><thead>    <tr>        <th class="col_heading level0 col0" >date</th>        <th class="col_heading level0 col1" >ext_price</th>        <th class="col_heading level0 col2" >pct_of_total</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row0_col0" class="data row0 col0" >2018-01</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row0_col1" class="data row0 col1" >185,362</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row0_col2" class="data row0 col2" >9.18%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row1_col0" class="data row1 col0" >2018-02</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row1_col1" class="data row1 col1" >146,212</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row1_col2" class="data row1 col2" >7.24%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row2_col0" class="data row2 col0" >2018-03</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row2_col1" class="data row2 col1" >203,921</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row2_col2" class="data row2 col2" >10.10%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row3_col0" class="data row3 col0" >2018-04</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row3_col1" class="data row3 col1" >174,574</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row3_col2" class="data row3 col2" >8.65%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row4_col0" class="data row4 col0" >2018-05</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row4_col1" class="data row4 col1" >165,419</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row4_col2" class="data row4 col2" >8.19%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row5_col0" class="data row5 col0" >2018-06</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row5_col1" class="data row5 col1" >174,089</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row5_col2" class="data row5 col2" >8.62%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row6_col0" class="data row6 col0" >2018-07</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row6_col1" class="data row6 col1" >191,662</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row6_col2" class="data row6 col2" >9.49%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row7_col0" class="data row7 col0" >2018-08</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row7_col1" class="data row7 col1" >153,779</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row7_col2" class="data row7 col2" >7.62%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row8_col0" class="data row8 col0" >2018-09</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row8_col1" class="data row8 col1" >168,443</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row8_col2" class="data row8 col2" >8.34%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row9_col0" class="data row9 col0" >2018-10</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row9_col1" class="data row9 col1" >171,495</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row9_col2" class="data row9 col2" >8.49%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row10_col0" class="data row10 col0" >2018-11</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row10_col1" class="data row10 col1" >119,961</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row10_col2" class="data row10 col2" >5.94%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row11_col0" class="data row11 col0" >2018-12</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row11_col1" class="data row11 col1" >163,867</td>
#                         <td id="T_4a8327f8_3ffc_11eb_93d5_a4bb6d40d5e5row11_col2" class="data row11 col2" >8.12%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 2.2 Highlight using gradient
#
# Another useful function is the [`background_gradient`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.io.formats.style.Styler.background_gradient.html) which can highlight the range of values in a column. Use `cmap` to choose a color palette for the gradient. The matplotlib [documentation](https://matplotlib.org/tutorials/colors/colormaps.html) lists all the available colormap options.

# %%
monthly_sales.style.format(formatter).hide_index()\
    .background_gradient(subset=['ext_price'], cmap='OrRd')
# Out:
# <style  type="text/css" >
#     #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row0_col1 {
#             background-color:  #ce2417;
#             color:  #f1f1f1;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row1_col1 {
#             background-color:  #fdc791;
#             color:  #000000;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row2_col1 {
#             background-color:  #7f0000;
#             color:  #f1f1f1;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row3_col1 {
#             background-color:  #ea5a3f;
#             color:  #000000;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row4_col1 {
#             background-color:  #f88053;
#             color:  #000000;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row5_col1 {
#             background-color:  #eb5c41;
#             color:  #000000;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row6_col1 {
#             background-color:  #b90805;
#             color:  #f1f1f1;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row7_col1 {
#             background-color:  #fdb07a;
#             color:  #000000;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row8_col1 {
#             background-color:  #f4754f;
#             color:  #000000;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row9_col1 {
#             background-color:  #f06849;
#             color:  #000000;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row10_col1 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row11_col1 {
#             background-color:  #fa8656;
#             color:  #000000;
#         }</style><table id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5" ><thead>    <tr>        <th class="col_heading level0 col0" >date</th>        <th class="col_heading level0 col1" >ext_price</th>        <th class="col_heading level0 col2" >pct_of_total</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row0_col0" class="data row0 col0" >2018-01</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row0_col1" class="data row0 col1" >185,362</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row0_col2" class="data row0 col2" >9.18%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row1_col0" class="data row1 col0" >2018-02</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row1_col1" class="data row1 col1" >146,212</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row1_col2" class="data row1 col2" >7.24%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row2_col0" class="data row2 col0" >2018-03</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row2_col1" class="data row2 col1" >203,921</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row2_col2" class="data row2 col2" >10.10%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row3_col0" class="data row3 col0" >2018-04</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row3_col1" class="data row3 col1" >174,574</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row3_col2" class="data row3 col2" >8.65%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row4_col0" class="data row4 col0" >2018-05</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row4_col1" class="data row4 col1" >165,419</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row4_col2" class="data row4 col2" >8.19%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row5_col0" class="data row5 col0" >2018-06</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row5_col1" class="data row5 col1" >174,089</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row5_col2" class="data row5 col2" >8.62%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row6_col0" class="data row6 col0" >2018-07</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row6_col1" class="data row6 col1" >191,662</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row6_col2" class="data row6 col2" >9.49%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row7_col0" class="data row7 col0" >2018-08</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row7_col1" class="data row7 col1" >153,779</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row7_col2" class="data row7 col2" >7.62%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row8_col0" class="data row8 col0" >2018-09</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row8_col1" class="data row8 col1" >168,443</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row8_col2" class="data row8 col2" >8.34%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row9_col0" class="data row9 col0" >2018-10</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row9_col1" class="data row9 col1" >171,495</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row9_col2" class="data row9 col2" >8.49%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row10_col0" class="data row10 col0" >2018-11</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row10_col1" class="data row10 col1" >119,961</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row10_col2" class="data row10 col2" >5.94%</td>
#             </tr>
#             <tr>
#                                 <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row11_col0" class="data row11 col0" >2018-12</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row11_col1" class="data row11 col1" >163,867</td>
#                         <td id="T_4dd947e2_3ffc_11eb_8620_a4bb6d40d5e5row11_col2" class="data row11 col2" >8.12%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 2.3 Highlight bar
#
# The pandas styling function also supports drawing [bar](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.io.formats.style.Styler.bar.html) charts within the columns. `bar` method has a few control parameters:
#
# - color
# - axis
# - subset
# - align: How to align the bars with the cells.
#
#     * ‘left’ : the min value starts at the left of the cell.
#
#     * ‘zero’ : a value of zero is located at the center of the cell.
#
#     * ‘mid’ : the center of the cell is at (max-min)/2, or if values are all negative (positive) the zero is aligned at the right (left) of the cell
# - vmin: Minimum bar value, defining the left hand limit of the bar drawing range, lower values are clipped to vmin. When None (default): the minimum value of the data will be used.
# - vmax: Maximum bar value.

# %%
monthly_sales.style.format(formatter).hide_index()\
    .bar(color='#FFA07A', vmin=100_000, subset=['ext_price'], align='zero')\
    .bar(color='lightgreen', vmin=0, subset=['pct_of_total'], align='zero')\
    .set_caption('2018 Sales Performance')
# Out:
# <style  type="text/css" >
#     #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 95.4%, transparent 95.4%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 95.4%, transparent 95.4%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 85.8%, transparent 85.8%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 85.8%, transparent 85.8%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 100.0%, transparent 100.0%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 100.0%, transparent 100.0%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 92.8%, transparent 92.8%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 92.8%, transparent 92.8%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 90.6%, transparent 90.6%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 90.6%, transparent 90.6%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 92.7%, transparent 92.7%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 92.7%, transparent 92.7%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 97.0%, transparent 97.0%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 97.0%, transparent 97.0%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 87.7%, transparent 87.7%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 87.7%, transparent 87.7%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 91.3%, transparent 91.3%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 91.3%, transparent 91.3%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 92.0%, transparent 92.0%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 92.0%, transparent 92.0%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 79.4%, transparent 79.4%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 79.4%, transparent 79.4%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #FFA07A 50.0%, #FFA07A 90.2%, transparent 90.2%);
#         }    #T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, lightgreen 50.0%, lightgreen 90.2%, transparent 90.2%);
#         }</style><table id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5" ><caption>2018 Sales Performance</caption><thead>    <tr>        <th class="col_heading level0 col0" >date</th>        <th class="col_heading level0 col1" >ext_price</th>        <th class="col_heading level0 col2" >pct_of_total</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row0_col0" class="data row0 col0" >2018-01</td>
#                         <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row0_col1" class="data row0 col1" >185,362</td>
#                         <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row0_col2" class="data row0 col2" >9.18%</td>
#             </tr>
#             <tr>
#                                 <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row1_col0" class="data row1 col0" >2018-02</td>
#                         <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row1_col1" class="data row1 col1" >146,212</td>
#                         <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row1_col2" class="data row1 col2" >7.24%</td>
#             </tr>
#             <tr>
#                                 <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row2_col0" class="data row2 col0" >2018-03</td>
#                         <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row2_col1" class="data row2 col1" >203,921</td>
#                         <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row2_col2" class="data row2 col2" >10.10%</td>
#             </tr>
#             <tr>
#                                 <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row3_col0" class="data row3 col0" >2018-04</td>
#                         <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row3_col1" class="data row3 col1" >174,574</td>
#                         <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row3_col2" class="data row3 col2" >8.65%</td>
#             </tr>
#             <tr>
#                                 <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row4_col0" class="data row4 col0" >2018-05</td>
#                         <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row4_col1" class="data row4 col1" >165,419</td>
#                         <td id="T_51aa03ac_3ffc_11eb_9eaa_a4bb6d40d5e5row4_col2" class="data row4 col2" >8.19%</td>

# %% [markdown]
# ## 3. Sparklines
#
# `sparklines` is not a pandas built-in styling. Install this package and refer to this [example](https://pbpython.com/styling-pandas.html). It can shows mini distribution maps in the data cells and make the data easier to read.
